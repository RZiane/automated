# %%
with open(r"C:\Users\T4567\Stage_crisco\Stage_1\HOPS\phrases_13eme.txt", "r", encoding="utf-8") as F:
    L_Namephrase13= F.readlines()

# %%
from conllu import parse 
with open(r"C:\Users\T4567\Stage_crisco\Stage_1\HOPS\13e_Histoire_duc.conllu", "r", encoding="utf-8") as F:
    Conllu13e= F.read()
    sentences13= parse(Conllu13e)
    print(sentences13)
# Out:
# [TokenList<Par, la, devision, que, li, anciien, home, fisent, dou, monde, ,, savons, nous, que, toute, la, tierre, est, enclose, de, la, grant, mer, ,, ke, on, apiele, Occean, ,, qui, entre, par, bras, dedens, la, tierre, et, la, devise, en, .iij., principaus, parties, ,, dont, la, maistre, est, apielée, Ayse, por, chou, qu', ele, tient, en, soi, la, moitié, del, monde, ;, metadata={sent_id: "1_1_1_1_1"}>, TokenList<li, autre, est, apielée, Aufrike, ;, metadata={sent_id: "1_1_1_1_2"}>, TokenList<la, tierce, ù, nos, >sommes, si, est, apielée, Europe, ,, qui, por, la, plenté, des, douces, aighes, est, abitée, de, moult, de, gens, ., metadata={sent_id: "1_1_1_1_3"}>, TokenList<En, iceste, Europe, fu, anciienement, Germanie, ,, qui, ore, est, apielée, Alemaigne, ;, metadata={sent_id: "1_1_1_1_4"}>, TokenList<là, sourt, uns, flueves, qui, est, apielés, Hyster, et, court, en, Sassoigne, ,, qui, est, apielés, et, açains, de, moult, d', autres, flueves, ,, tant, qu', il, chiet, en, la, Dynoe
# ...

# %%
with open(r"C:\Users\T4567\Stage_crisco\Stage_1\HOPS\1665_Abrege.conllu", "r", encoding="utf-8") as F:
    Conllu13e= F.read()
    sentences17= parse(Conllu13e)

# %%
newfile= []
list_13= []
with open(r"C:\Users\T4567\Stage_crisco\Stage_1\HOPS\Phrase13test.conllu", "w", encoding="utf-8") as F:
    for _id in L_Namephrase13:
        list_13.append(_id.rstrip("\n"))
    for sent in sentences13: 
        if sent.metadata["sent_id"] in list_13:
            newfile.append(sent)
        F.writelines([sentence.serialize() + "" for sentence in newfile])
# Out:
# <class 'str'>
# 1_1_1_1_1
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# 1_1_1_1_23
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# ...

# %%
newfile= []
list_17= []
with open(r"C:\Users\T4567\Stage_crisco\Stage_1\HOPS\Phrase17test.conllu", "w", encoding="utf-8") as F:
    for _id in L_Namephrase17:
        list_17.append(_id.rstrip("\n"))
    for sent in sentences17: 
        if sent.metadata["sent_id"] in list_17:
            newfile.append(sent)
        F.writelines([sentence.serialize() + "" for sentence in newfile])
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# 1_1_1_1_5
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# 1_1_1_3_1
# <class 'str'>
# 1_1_1_3_2
# <class 'str'>
# <class 'str'>
# <class 'str'>
# 1_1_1_3_5
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# 1_1_1_5_5
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# ...
